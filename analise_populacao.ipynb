# %%
import pandas

# %%
df =  pandas.read_csv("estimativa_TCU_2017_20180207.csv")

# %%
df['POPULACAO_ESTIMADA'].apply(int)
# Out:
# 0         25437
# 1        107345
# 2          6224
# 3         88507
# 4         17934
# 5         18467
# 6          8659
# 7         17400
# 8         33030
# 9         47451
# 10        55871
# 11       132667
# 12        38609
# 13        21747
# 14        39759
# 15        38051
# 16       519436
# 17        22124
# 18         3829
# 19        57074
# 20         8198
# 21        95630
# 22        24181
# 23        28891
# 24        16747
# 25        14045
# 26        20916
# 27        39044
# 28        10051
# 29         6460
#          ...
# 5540      33118
# 5541       5071
# 5542      22684
# 5543       4037
# 5544       2070
# 5545      19697
# 5546     105459
# 5547       8323
# 5548      20478
# 5549       6891
# 5550       2998
# 5551       3625
# 5552       3363
# 5553       7634
# 5554       2900
# 5555     121266
# 5556       3571
# 5557       4818
# 5558       5050
# 5559       2961
# 5560      40082
# 5561      14195
# 5562       3154
# 5563     159500
# ...

# %%
df[df['POPULACAO_ESTIMADA'] < 5000]
# Out:
#       UF  COD_UF  COD_MUNIC              NOME_MUNICIPIO  POPULACAO_ESTIMADA
# 18    RO      11        262                  Rio Crespo                3829
# 32    RO      11        908                Castanheiras                3550
# 42    RO      11       1468        Pimenteiras do Oeste                2410
# 43    RO      11       1476       Primavera de Rondônia                3411
# 47    RO      11       1559               Teixeirópolis                4931
# 105   AM      13       2108                      Japurá                4205
# 167   PA      15       1253                     Bannach                3200
# 307   AP      16        550                    Pracuúba                4779
# 311   TO      17        251                 Abreulândia                2571
# 317   TO      17       1051                      Angico                3423
# 318   TO      17       1101      Aparecida do Rio Negro                4726
# ...
